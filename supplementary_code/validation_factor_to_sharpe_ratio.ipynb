# %%
val_sharpe_test_sharpe_ewp_sharpe = [
    (1.1658, 0.7190706339, 1.817869627),
    (1.012, 0.9772465822, 1.817869627), 
    (1.3786, 0.4424751143, 1.817869627),
    (1.4185, 1.466865635, 1.817869627),
    (1.4811, 1.755631595 , 1.817869627),
    (1.2647, 0.04981075259, 1.817869627),
    (0.9509, 1.838939321 , 1.817869627),
    (1.1199, 2.16345274 , 1.817869627),
    (0.8074, -1.346843205,-0.6529297074),
    (0.9728, -0.7434850545,-0.6529297074),
    (1.0166,-1.359310975,-0.6529297074),
    (1.0689,-2.088896926,-0.6529297074),
    (0.9828,-0.3475052983,-0.6529297074),
    (1.1455,-1.151222787,-0.6529297074),
    (1.0051,-1.63964852,-0.6529297074),
    (1.0987,-1.248272926,-0.6529297074),
    (0.8513,0.864201432,0.7575545811),
    (1.009,0.9868469071,0.7575545811),
    (1.0824,0.5349832099,0.7575545811),
    (0.7446,-0.01619503863,0.7575545811),
    (0.9482,0.2783416336,0.7575545811),
    (1.013,1.293446595,0.7575545811),
    (0.7341,0.65791439,0.7575545811),
    (1.0032,0.6634516385,0.7575545811),
    (0.7816,-0.9128221073,-0.5664529816),
    (1.2248,-0.5877657819,-0.5664529816),
    (1.0247,-1.422689459,-0.5664529816),
    (1.0457,-0.4546953659,-0.5664529816),
    (0.7645,0.03946218146,-0.5664529816),
    (0.9913,-0.06505256121,-0.5664529816),
    (1.1115,-1.208157408,-0.5664529816),
    (0.7763,-1.248760584,-0.5664529816),
    (0.6117,2.172567889,1.674407183),
    (1.008,1.867369445,1.674407183),
    (1.0606,0.2306590936,1.674407183),
    (1.5861,1.574521804,1.674407183),
    (0.9314,1.307615894,1.674407183),
    (0.8692,1.607214207,1.674407183),
    (0.5979,1.481370106,1.674407183),
    (1.3471,1.190350843,1.674407183),
    (0.489,0.6150530318,0.2877034998),
    (1.172,0.5290645696,0.2877034998),
    (1.2045,0.8356575175,0.2877034998),
    (1.6635,0.1753578788,0.2877034998),
    (1.3056,0.4627407825,0.2877034998),
    (1.2359,0.7962109249,0.2877034998),
    (1.4347,0.1064719989,0.2877034998),
    (1.2348,0.02638112954,0.2877034998),
    
    
]

# %%
superiority_ratios = [
    (t[0], t[1]/t[2]) for t in val_sharpe_test_sharpe_ewp_sharpe 
]

# %%
import matplotlib.pyplot as plt

# Assuming the unpacked data
val_ratios, backtest_ratios = zip(*superiority_ratios)

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(val_ratios, backtest_ratios, color='blue', marker='o')
#plt.title('av. Validation')
plt.xlabel('av. Validation Superiority Ratio')  # Setting the x-axis label
plt.ylabel('1 Year Backtest Superiority Ratio')  # Setting the y-axis label
plt.grid(True)
plt.show()
