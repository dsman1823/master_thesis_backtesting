# %%
import torch

import matplotlib.pyplot as plt
import numpy as np,pandas as pd

from sklearn.neighbors import KernelDensity
from scipy.optimize import minimize
from scipy.linalg import block_diag
from sklearn.covariance import LedoitWolf, MinCovDet
from deepdowmine.nn import BachelierNetWithShorting, BachelierNet, BachelierNetWithShortingUpd

import cvxpy as cp

# %%
def corr2cov(corr, std):
    cov = corr * np.outer(std, std)
    return cov

# %%
#Generate a block-diagnoal covariance matrix and a vector of means
# Block represent sector
# bSize  number of assets in the sector
# bCorr correlation between assets in the sector
def formBlockMatrix(nBlocks, bSize, bCorr):
    block = np.ones( (bSize, bSize))*bCorr
    block[range(bSize), range(bSize)] = 1 #diagonal is 1
    corr = block_diag(*([block]*nBlocks))
    return corr



def formTrueMatrix(nBlocks, bSize, bCorr):
    corr0 = formBlockMatrix(nBlocks, bSize, bCorr)
    corr0 = pd.DataFrame(corr0)
    cols = corr0.columns.tolist()
    np.random.shuffle(cols)
    corr0 = corr0[cols].loc[cols].copy(deep=True)
    std0 = np.random.uniform(.05, .2, corr0.shape[0])
    cov0 = corr2cov(corr0, std0)
    mu0 = np.random.normal(std0, std0, cov0.shape[0]).reshape(-1,1)
    return mu0, cov0

def corr2cov(corr, std):
    cov = corr * np.outer(std, std)
    return cov

# Denoising of the empirical covariance matrix
# by constant residual eigenvalue method
def deNoiseCov(cov0,q,bWidth):
    corr0=cov2corr(cov0)
    eVal0,eVec0=getPCA(corr0)
    eMax0,var0=findMaxEval(np.diag(eVal0),q,bWidth)
    nFacts0=eVal0.shape[0]-np.diag(eVal0)[::-1].searchsorted(eMax0)
    corr1=denoisedCorr(eVal0,eVec0,nFacts0)
    cov1=corr2cov(corr1,np.diag(cov0)**.5)
    return cov1


# function to obtain empirical from true matrix with and without shrink
def simCovMu(mu0,cov0,nObs,shrink=False):
    x=np.random.multivariate_normal(mu0.flatten(),cov0,size=nObs)
    mu1=x.mean(axis=0).reshape(-1,1)
    if shrink:cov1=LedoitWolf().fit(x).covariance_
    else:cov1=np.cov(x,rowvar=0)
    return mu1,cov1, x


def simCovMuRob(mu0,cov0,nObs):
    x=np.random.multivariate_normal(mu0.flatten(),cov0,size=nObs)
    mu1=x.mean(axis=0).reshape(-1,1)
    cov1=MinCovDet().fit(x).covariance_
    return mu1,cov1, x


# replace in random eigenvalues by constants
def denoisedCorr(eVal, eVec, nFacts):
    eVal_ = np.diag(eVal).copy()
    eVal_[nFacts:] = eVal_[nFacts:].sum()/float(eVal_.shape[0] - nFacts) #all but 0..i values equals (1/N-i)sum(eVal_[i..N]))
    eVal_ = np.diag(eVal_) #square matrix with eigenvalues as diagonal: eVal_.I
    corr1 = np.dot(eVec, eVal_).dot(eVec.T) #Eigendecomposition of a symmetric matrix: S = QΛQT
    corr1 = cov2corr(corr1) # Rescaling the correlation matrix to have 1s on the main diagonal
    return corr1


def getRndCov(nCols, nFacts): #nFacts - contains signal out of nCols
    w = np.random.normal(size=(nCols, nFacts))
    cov = np.dot(w, w.T) #random cov matrix, however not full rank
    cov += np.diag(np.random.uniform(size=nCols)) #full rank cov
    return cov

def cov2corr(cov):
    # Derive the correlation matrix from a covariance matrix
    std = np.sqrt(np.diag(cov))
    corr = cov/np.outer(std,std)
    corr[corr<-1], corr[corr>1] = -1,1 #for numerical errors
    return corr
    
def corr2cov(corr, std):
    cov = corr * np.outer(std, std)
    return cov     
    
#snippet 2.4 - fitting the marcenko-pastur pdf - find variance
#Fit error
def errPDFs(var, eVal, q, bWidth, pts=1000):
    var = var[0]
    pdf0 = mpPDF(var, q, pts) #theoretical pdf
    pdf1 = fitKDE(eVal, bWidth, x=pdf0.index.values) #empirical pdf
    sse = np.sum((pdf1-pdf0)**2)
    print("sse:"+str(sse))
    return sse 
    
# find max random eVal by fitting Marcenko's dist
# and return variance
def findMaxEval(eVal, q, bWidth):
    out = minimize(lambda *x: errPDFs(*x), x0=np.array(0.5), args=(eVal, q, bWidth), bounds=((1E-5, 1-1E-5),))
    print("found errPDFs"+str(out['x'][0]))
    if out['success']: var = out['x'][0]
    else: var=1
    eMax = var*(1+(1./q)**.5)**2
    return eMax, var



def getPCA(matrix):
# Get eVal,eVec from a !!!Hermitian matrix (cov matrix is a hermitian matrix)
    eVal,eVec=np.linalg.eigh(matrix) 
    indices=eVal.argsort()[::-1] # arguments for sorting eVal desc
    eVal,eVec=eVal[indices],eVec[:,indices]
    eVal=np.diagflat(eVal)
    return eVal,eVec


def fitKDE(obs,bWidth=.25,kernel='gaussian',x=None):
    # Fit kernel to a series of obs, and derive the prob of obs
    # x is the array of values on which the fit KDE will be evaluated
    if len(obs.shape)==1:obs=obs.reshape(-1,1)
    kde=KernelDensity(kernel=kernel,bandwidth=bWidth).fit(obs)
    if x is None:x=np.unique(obs).reshape(-1,1)
    if len(x.shape)==1:x=x.reshape(-1,1)
    logProb=kde.score_samples(x) # log(density)
    pdf=pd.Series(np.exp(logProb),index=x.flatten())
    return pdf


def mpPDF(var,q,pts):
    # Marcenko-Pastur pdf
    # q=T/N (>1)
    # pts - amount of points
    eMin,eMax=var*(1-(1./q)**.5)**2,var*(1+(1./q)**.5)**2
    eVal=np.linspace(eMin,eMax,pts)
    pdf=q/(2*np.pi*var*eVal)*((eMax-eVal)*(eVal-eMin))**.5
    pdf=pd.Series(pdf,index=eVal)
    return pdf


def getRndCov(nCols, nFacts): #nFacts - contains signal out of nCols
    w = np.random.normal(size=(nCols, nFacts))
    cov = np.dot(w, w.T) #random cov matrix, however not full rank
    cov += np.diag(np.random.uniform(size=nCols)) #full rank cov
    return cov

def cov2corr(cov):
    # Derive the correlation matrix from a covariance matrix
    std = np.sqrt(np.diag(cov))
    corr = cov/np.outer(std,std)
    corr[corr<-1], corr[corr>1] = -1,1 #for numerical errors
    return corr
    
def corr2cov(corr, std):
    cov = corr * np.outer(std, std)
    return cov     
    
#snippet 2.4 - fitting the marcenko-pastur pdf - find variance
#Fit error
def errPDFs(var, eVal, q, bWidth, pts=1000):
    var = var[0]
    pdf0 = mpPDF(var, q, pts) #theoretical pdf
    pdf1 = fitKDE(eVal, bWidth, x=pdf0.index.values) #empirical pdf
    sse = np.sum((pdf1-pdf0)**2)
    print("sse:"+str(sse))
    return sse 
    
# find max random eVal by fitting Marcenko's dist
# and return variance
def findMaxEval(eVal, q, bWidth):
    out = minimize(lambda *x: errPDFs(*x), x0=np.array(0.5), args=(eVal, q, bWidth), bounds=((1E-5, 1-1E-5),))
    print("found errPDFs"+str(out['x'][0]))
    if out['success']: var = out['x'][0]
    else: var=1
    eMax = var*(1+(1./q)**.5)**2
    return eMax, var


# find min var portfolio
def optPort(cov,mu=None):
    inv=np.linalg.inv(cov)
    ones=np.ones(shape=(inv.shape[0],1))
    if mu is None:mu=ones
    w=np.dot(inv,mu)
    w/=np.dot(ones.T,w)
    return w




def minimize_portfolio_variance(cov_matrix):
    """
    Finds the portfolio weights that minimize the portfolio variance.
    
    :param cov_matrix: The covariance matrix of asset returns.
    :return: Optimal portfolio weights as a numpy array.
    """
    # Number of assets
    n = cov_matrix.shape[0]

    # Portfolio weights variables
    w = cp.Variable(n)

    # Portfolio variance
    port_variance = cp.quad_form(w, cov_matrix)

    # Objective Function: Minimize portfolio variance
    objective = cp.Minimize(port_variance)

    # Constraints: weights sum to 1, non-negativity
    constraints = [cp.sum(w) == 1]

    # Problem
    problem = cp.Problem(objective, constraints)
    
    # Solve the problem
    problem.solve()

    # Portfolio weights
    optimal_weights = w.value
    
    return optimal_weights


def transform_returns_to_Xy_tensors(returns, lookback, n_timesteps, horizon, gap):
    X_list, y_list = [], []

    for i in range(lookback, n_timesteps - horizon - gap + 1):
        X_list.append(returns[i - lookback: i, :])
        y_list.append(returns[i + gap: i + gap + horizon, :])

    X = np.stack(X_list, axis=0)[:, None, ...]
    y = np.stack(y_list, axis=0)[:, None, ...]
    
    return X, y

def X_to_tensor(X, loockback, i = None):
    
    
    if i:
        if i < loockback:
            raise ValueError("i must not be greater than lookback")
    else: i = -1
    # Parameters
    i = len(X) if i == -1 else i

    # Slicing X and reshaping
    X_slice = X[i - lookback: i, :]  # This is (40, 250)
    X_tensor = torch.tensor(X_slice).unsqueeze(0).unsqueeze(0)  # Adding two dimensions
    return torch.tensor(X_tensor, dtype=torch.float32)

# %%
lookback, gap, horizon = 40, 0, 20

# %%
# Should be run after the code below to obtain X!!!
n_timesteps, n_assets = X.shape
# tX, ty = transform_returns_to_Xy_tensors(X, lookback, n_timesteps, horizon, gap)
# res = torch.tensor(tX[[-1]], dtype=torch.float32)#(X[indices_train], dtype=torch.float32) #indices_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Should be run after the code below to obtain X!!!
# ----> 2 n_timesteps, n_assets = X.shape
#
# NameError: name 'X' is not defined

# %% [markdown]
# # !!!!!!!!!!!!! Recheck how deep dow trains the data

# %%
tensorX = X_to_tensor(X, 40)

# %%
tensorX.shape

# %%
X[[999], 0]

# %%
tensorX[0, 0, 39, 0]

# %%
X[[959, 960, 961], 0]

# %%
tensorX[0, 0, 0, 0]

# %%
arr = X[0:1000, 0]
value_to_find = 0.0678

# Since we are dealing with floating-point numbers, we use a small tolerance
tolerance = 1e-4

# Finding indices where value matches
indices = np.where(np.abs(arr - value_to_find) < tolerance)
indices

# %% [markdown]
# # !!!! End recheck

# %%
network = network = BachelierNetWithShortingUpd(#BachelierNet(
        1,
        250,
        hidden_size=32,
        shrinkage_strategy="diagonal",
        p=0.5,
    )
#

# %% [markdown]
# # Experiment max sharpe

# %%
# network.load_state_dict(torch.load('bachelier_with_shorting_250assets_max_sharpe_ratio_loss.pth'))


# np.random.seed(32)
# # block is a sector with bSize assets
# nBlocks, bSize, bCorr = 2, 125, .01 #5, 50, .5
# np.random.seed(0)
# mu0, cov0 = formTrueMatrix(nBlocks, bSize, bCorr)

# nObs, nTrials, bWidth, shrink = 1000, 15, .01, False
# w1 = pd.DataFrame(columns = range(cov0.shape[0]), index = range(nTrials), dtype=float)
# w1_d = w1.copy(deep=True)
# w1_n = w1.copy(deep=True)

# covs1 = []
# covs1_d = []
# covs1_n = []
# np.random.seed(0)
# for i in range(nTrials):
#     mu1, cov1, X = simCovMu(mu0, cov0, nObs, shrink = shrink)
#     cov1_d = deNoiseCov(cov1, nObs*1./cov1.shape[1], bWidth)
#     w1.loc[i] = optPort(cov1,mu1).flatten()   #optPort(cov1, mu1).flatten() # add column vector w as row in w1
#     w1_d.loc[i] = optPort(cov1_d,mu1).flatten() #optPort(cov1_d, mu1).flatten() # np.sum(w1_d, axis=1) is vector of 1's. sum(np.sum(w1_d, axis=0)= nTrials
#     # so minimum-variance-portfolio is 1./nTrials*(np.sum(w1_d, axis=0)) - but distribution not stationary
#     tensorX = X_to_tensor(X, lookback)
#     weights_n = network(tensorX)
#     w1_n.loc[i] = weights_n.detach().numpy().flatten()#network(tensorX)
    
    
#     covs1.append(cov1)
#     covs1_d.append(cov1_d)
    
# min_var_port = 1./nTrials*(np.sum(w1_d, axis=0)) 
# #code snippet 2.11
# w0 = optPort(cov0, mu0) # w0 true percentage asset allocation
# w0 = np.repeat(w0.T, w1.shape[0], axis=0) 
# rmsd = np.mean((w1-w0).values.flatten()**2)**.5     #RMSE not denoised
# rmsd_d = np.mean((w1_d-w0).values.flatten()**2)**.5 #RMSE denoised
# rmsd_n = np.mean((w1_n-w0).values.flatten()**2)**.5 #
# print("RMSE not denoised:"+str( rmsd))
# print("RMSE denoised:"+str( rmsd_d))
# print("RMSE neural:"+str( rmsd_n))

# %% [markdown]
# # Min var opt

# %% [markdown]
# ## Not shrunk

# %%
# network.load_state_dict(torch.load('bachelier_with_shorting_250assets_min_var_loss.pth'))


np.random.seed(32)
# block is a sector with bSize assets
nBlocks, bSize, bCorr =10, 50, .5
np.random.seed(0)
mu0, cov0 = formTrueMatrix(nBlocks, bSize, bCorr)
Xs = []

nObs, nTrials, bWidth, shrink, minVarPortf = 10000, 15, .01, False, True
w1 = pd.DataFrame(columns = range(cov0.shape[0]), index = range(nTrials), dtype=float)
w1_d = w1.copy(deep=True)
# w1_n = w1.copy(deep=True)

covs1 = []
covs1_d = []
covs1_n = []
np.random.seed(0)
for i in range(nTrials):
    mu1, cov1, X = simCovMu(mu0, cov0, nObs, shrink = shrink)
    Xs.append(X)
    if minVarPortf: mu1 = None
    cov1_d = deNoiseCov(cov1, nObs*1./cov1.shape[1], bWidth)
    w1.loc[i] = minimize_portfolio_variance(cov1).flatten()   #optPort(cov1, mu1).flatten() # add column vector w as row in w1
    w1_d.loc[i] = minimize_portfolio_variance(cov1_d).flatten() #optPort(cov1_d, mu1).flatten() # np.sum(w1_d, axis=1) is vector of 1's. sum(np.sum(w1_d, axis=0)= nTrials
    # so minimum-variance-portfolio is 1./nTrials*(np.sum(w1_d, axis=0)) - but distribution not stationary
   # tensorX = X_to_tensor(X, lookback)
   # weights_n = network(tensorX)
   # w1_n.loc[i] = weights_n.detach().numpy().flatten()#network(tensorX)
    
    
    covs1.append(cov1)
    covs1_d.append(cov1_d)
    
min_var_port = 1./nTrials*(np.sum(w1_d, axis=0)) 
#code snippet 2.11
w0 = optPort(cov0, None if minVarPortf else mu0) # w0 true percentage asset allocation
w0 = np.repeat(w0.T, w1.shape[0], axis=0) 
rmsd = np.mean((w1-w0).values.flatten()**2)**.5     #RMSE not denoised
rmsd_d = np.mean((w1_d-w0).values.flatten()**2)**.5 #RMSE denoised
#rmsd_n = np.mean((w1_n-w0).values.flatten()**2)**.5 #
print("RMSE not denoised:"+str( rmsd))
print("RMSE denoised:"+str( rmsd_d))
#print("RMSE neural:"+str( rmsd_n))
# Out:
# sse:6.7788248961284
# sse:6.778827138512861
# sse:13774890325380.236
# sse:13747381814369.688
# sse:6744.109356768681
# sse:6744.108357725492
# sse:6.7437814620639775
# sse:6.743780279929175
# sse:6.730496772778256
# sse:6.730496779171952
# sse:6.730496385915422
# sse:6.730496385933165
# sse:6.730496385921468
# sse:6.730496385921329
# sse:6.730496385915857
# sse:6.730496385931595
# sse:6.730496385915527
# sse:6.730496385933009
# sse:6.730496385915535
# sse:6.730496385933132
# sse:6.730496385915447
# sse:6.730496385933162
# sse:6.730496385915422
# sse:6.730496385933165
# sse:6.730496385915501
# sse:6.730496385933234
# sse:6.730496385915422
# sse:6.730496385933165
# sse:6.730496385915534
# sse:6.730496385933138
# sse:6.730496385915422
# sse:6.730496385933165
# sse:6.730496385915476
# sse:6.7304963859330975
# sse:6.730496385915422
# sse:6.730496385933165
# sse:6.730496385915414
# sse:6.730496385933115
# sse:6.730496385915467
# sse:6.730496385933176
# sse:7.5667371621206385
# sse:7.566727677011555
# sse:6.730496385921224
# sse:6.730496385921281
# sse:6.730496385915916
# sse:6.730496385931538
# sse:6.730496385915534
# sse:6.730496385933035
# sse:6.7304963859155045
# sse:6.730496385933215
# sse:6.730496385915517
# sse:6.730496385933241
# sse:6.730496385915422
# sse:6.730496385933165
# sse:6.7304963859155285
# sse:6.73049638593315
# sse:6.730496385915422
# sse:6.730496385933165
# sse:6.730496385915498
# sse:6.730496385933103
# sse:6.730496385915422
# sse:6.730496385933165
# sse:6.73049638591547
# sse:6.730496385933186
# sse:6.730496385915422
# sse:6.730496385933165
# sse:6.730496385915476
# sse:6.730496385933203
# sse:6.730496385915422
# sse:6.730496385933165
# found errPDFs0.4995697422853397
# sse:6.928511090853221
# sse:6.928513637732731
# sse:13774890325380.236
# sse:13747381814369.688
# sse:6788.721092563378
# sse:6788.72011375299
# sse:6.881536122575764
# sse:6.881534934619187
# sse:6.868641930177996
# sse:6.868641936343723
# sse:6.868641584852814
# sse:6.868641584866853
# sse:6.868641584858062
# sse:6.868641584858069
# sse:6.868641584853024
# sse:6.868641584866023
# sse:6.868641584852792
# sse:6.8686415848667846
# sse:6.868641584853062
# sse:6.868641584866267
# sse:6.868641584852785
# sse:6.8686415848667535
# sse:6.868641584852932
# sse:6.8686415848664675
# sse:6.868641584852903
# sse:6.8686415848668005
# sse:6.868641584852844
# sse:6.868641584866794
# sse:6.868641584852785
# sse:6.8686415848667535
# found errPDFs0.49953069978909503
# sse:6.536134931919651
# sse:6.536136238641269
# sse:13774890325380.236
# sse:13747381814369.688
# sse:6789.233295735819
# sse:6789.2323322553875
# sse:6.524120379288059
# sse:6.52411977203076
# sse:6.520833623604776
# sse:6.520833625318825
# sse:6.520833598229098
# sse:6.520833598231289
# sse:6.520833598230068
# sse:6.520833598230199
# sse:6.52083359822907
# sse:6.520833598231382
# sse:6.520833598229008
# sse:6.520833598231256
# sse:6.520833598229538
# sse:6.520833598230732
# sse:6.520833598229013
# sse:6.520833598231255
# sse:6.5208335982290535
# sse:6.520833598231316
# sse:6.520833598229008
# sse:6.520833598231256
# found errPDFs0.499766021988471
# sse:6.203711871161917
# sse:6.203712456954674
# sse:13774890325380.236
# sse:13747381814369.688
# sse:6781.3399115579905
# sse:6781.338938931731
# sse:6.201088645620198
# sse:6.20108839123272
# sse:6.200479633366269
# sse:6.200479633522434
# sse:6.200479633214641
# sse:6.2004796332147585
# found errPDFs0.4998896587677224
# sse:7.236702137843765
# sse:7.236710210036518
# sse:13774890325380.236
# sse:13747381814369.688
# sse:6720.53559335166
# sse:6720.5346122515775
# sse:6.770182336288595
# sse:6.770178463617545
# sse:6.635659432565596
# sse:6.635659486836255
# sse:6.635632846616451
# sse:6.635632846908166
# sse:6.635632845993728
# sse:6.635632845993669
# found errPDFs0.4985189359910397
# sse:6.86662552410589
# sse:6.866631685427994
# sse:13774890325380.236
# sse:13747381814369.688
# sse:6759.481573872095
# sse:6759.480593463738
# sse:6.575036923054051
# sse:6.575034249090809
# sse:6.509154383412254
# sse:6.50915441356932
# sse:6.509145969250849
# sse:6.509145969380679
# sse:6.509145969159659
# sse:6.509145969159574
# found errPDFs0.4988443786353363
# sse:5.180477650848679
# sse:5.180476740213626
# sse:1307.6448772276362
# sse:1307.6448968719092
# sse:6.377430788502871
# sse:6.37744202321028
# sse:5.1727910087724585
# sse:5.172791006378406
# sse:5.1727909543719806
# sse:5.172790954369299
# sse:5.1727909543705275
# sse:5.172790954370532
# found errPDFs0.5001688697576685
# sse:7.4577106061811484
# sse:7.457708942670486
# sse:1318.629522814379
# sse:1318.629541648089
# sse:11.229309042414528
# sse:11.22932851986074
# sse:7.431393846703907
# sse:7.431393836797373
# sse:7.431392906411142
# sse:7.431392906394763
# sse:7.431392906400358
# sse:7.431392906400347
# found errPDFs0.5003165707087868
# sse:7.544930129891927
# sse:7.54492459200488
# sse:1308.97875851763
# sse:1308.9787764566952
# sse:44.43306164373533
# sse:44.433116588271794
# sse:7.279019728859536
# sse:7.279019662155037
# sse:7.27898055997151
# sse:7.278980559241976
# sse:7.278980554923706
# sse:7.27898055492357
# found errPDFs0.5009638126905774
# sse:5.854904166277112
# sse:5.854905297968019
# sse:13774890325380.236
# sse:13747381814369.688
# sse:6791.022118002543
# sse:6791.0211337408855
# sse:5.845853970341075
# sse:5.845853417889261
# sse:5.843030418969665
# sse:5.843030419601351
# sse:5.843030415592075
# sse:5.8430304155924055
# found errPDFs0.4997902330693078
# sse:7.975894870838895
# sse:7.975889040567043
# sse:1314.1185442861588
# sse:1314.118561326174
# sse:46.57068576142376
# sse:46.57074064845682
# sse:7.6556640407173955
# sse:7.65566381480175
# sse:7.655180654825097
# sse:7.655180654140114
# sse:7.655180650038691
# sse:7.65518065003842
# found errPDFs0.501100985351685
# sse:7.757082218135145
# sse:7.757074234237336
# sse:1310.0572149791085
# sse:1310.057232656623
# sse:70.0464578894435
# sse:70.04652290247697
# sse:7.156455770793848
# sse:7.156455568851602
# sse:7.156065404751704
# sse:7.156065402383294
# sse:7.156065349854384
# sse:7.156065349853549
# sse:7.156065349853992
# sse:7.1560653498540265
# found errPDFs0.501511009962604
# sse:7.855309695070872
# sse:7.855309392734326
# sse:1310.3717227580928
# sse:1310.3717428849613
# sse:7.985183920958534
# sse:7.985187604520561
# sse:7.854438593734958
# sse:7.854438593710423
# sse:7.854438593716894
# sse:7.8544385937168535
# found errPDFs0.5000576262784138
# sse:6.81205658398181
# sse:6.812054868297997
# sse:1310.5052614014912
# sse:1310.5052799676469
# sse:10.97925041595106
# sse:10.979270977074998
# sse:6.784853021910728
# sse:6.784853010012169
# sse:6.7848517035657405
# sse:6.784851703538111
# sse:6.784851703544966
# sse:6.7848517035448985
# found errPDFs0.50031736208877
# sse:7.2146749574084605
# sse:7.214667762843629
# sse:1311.751789885111
# sse:1311.7518105735471
# sse:57.30351666782508
# sse:57.303576936212075
# sse:6.719400475399675
# sse:6.719400194246849
# sse:6.718637460374742
# sse:6.718637458752556
# sse:6.718637434153962
# sse:6.71863743415336
# sse:6.718637434153555
# sse:6.718637434153711
# found errPDFs0.5013811660950189
# RMSE not denoised:0.001151762682355706
# RMSE denoised:0.0003672610803161896

# %% [markdown]
# ## Shrunk

# %%
# network.load_state_dict(torch.load('bachelier_with_shorting_250assets_min_var_loss.pth'))


np.random.seed(32)
# block is a sector with bSize assets
nBlocks, bSize, bCorr =10, 50, .5
np.random.seed(0)
mu0, cov0 = formTrueMatrix(nBlocks, bSize, bCorr)
Xs = []

nObs, nTrials, bWidth, shrink, minVarPortf = 10000, 15, .01, True, True
w1 = pd.DataFrame(columns = range(cov0.shape[0]), index = range(nTrials), dtype=float)
w1_d = w1.copy(deep=True)
# w1_n = w1.copy(deep=True)

covs1 = []
covs1_d = []
covs1_n = []
np.random.seed(0)
for i in range(nTrials):
    mu1, cov1, X = simCovMu(mu0, cov0, nObs, shrink = shrink)
    Xs.append(X)
    if minVarPortf: mu1 = None
    cov1_d = deNoiseCov(cov1, nObs*1./cov1.shape[1], bWidth)
    w1.loc[i] = minimize_portfolio_variance(cov1).flatten()   #optPort(cov1, mu1).flatten() # add column vector w as row in w1
    w1_d.loc[i] = minimize_portfolio_variance(cov1_d).flatten() #optPort(cov1_d, mu1).flatten() # np.sum(w1_d, axis=1) is vector of 1's. sum(np.sum(w1_d, axis=0)= nTrials
    # so minimum-variance-portfolio is 1./nTrials*(np.sum(w1_d, axis=0)) - but distribution not stationary
   # tensorX = X_to_tensor(X, lookback)
   # weights_n = network(tensorX)
   # w1_n.loc[i] = weights_n.detach().numpy().flatten()#network(tensorX)
    
    
    covs1.append(cov1)
    covs1_d.append(cov1_d)
    
min_var_port = 1./nTrials*(np.sum(w1_d, axis=0)) 
#code snippet 2.11
w0 = optPort(cov0, None if minVarPortf else mu0) # w0 true percentage asset allocation
w0 = np.repeat(w0.T, w1.shape[0], axis=0) 
rmsd = np.mean((w1-w0).values.flatten()**2)**.5     #RMSE not denoised
rmsd_d = np.mean((w1_d-w0).values.flatten()**2)**.5 #RMSE denoised
#rmsd_n = np.mean((w1_n-w0).values.flatten()**2)**.5 #
print("RMSE not denoised:"+str( rmsd))
print("RMSE denoised:"+str( rmsd_d))
#print("RMSE neural:"+str( rmsd_n))
# Out:
# sse:13.741536354262282
# sse:13.741518536759038
# sse:1313.6945493704338
# sse:1313.6945672618524
# sse:204.21091607191744
# sse:204.21100637038586
# sse:10.86118739887756
# sse:10.861187764550628
# sse:10.859911642078707
# sse:10.859911655869926
# sse:10.859909833668711
# sse:10.859909833656046
# sse:10.859909833660943
# sse:10.85990983366076
# found errPDFs0.5032732013036696
# sse:15.256928137631423
# sse:15.256909533378346
# sse:1322.0852929847624
# sse:1322.085312847858
# sse:213.42495383260962
# sse:213.42504637149074
# sse:12.232937273728886
# sse:12.232938063670996
# sse:12.227198154348496
# sse:12.227198183658803
# sse:12.227190277294508
# sse:12.227190277234152
# sse:12.227190277231056
# sse:12.227190277231042
# found errPDFs0.5032925086262803
# sse:14.511293079332502
# sse:14.511272786016187
# sse:1310.3371946291227
# sse:1310.3372148367218
# sse:235.6724870454185
# sse:235.67258009136802
# sse:11.022575138516135
# sse:11.022576308452921
# sse:11.010231982742162
# sse:11.010232034037426
# sse:11.010208336675774
# sse:11.010208336502107
# sse:11.01020833631799
# sse:11.010208336318211
# found errPDFs0.5034937498435047
# sse:14.345355149468007
# sse:14.34533485186803
# sse:1314.6541106512377
# sse:1314.6541295665138
# sse:237.8292777138801
# sse:237.82937156762733
# sse:10.661898572700213
# sse:10.661899076115684
# sse:10.659561371493904
# sse:10.659561383664828
# sse:10.659560012252943
# sse:10.659560012241
# sse:10.659560012245603
# sse:10.659560012245723
# found errPDFs0.5036525052993972
# sse:12.896477929670702
# sse:12.896464943051782
# sse:1320.439440333757
# sse:1320.439459239872
# sse:143.49736207605702
# sse:143.49744706343824
# sse:11.41820347523868
# sse:11.418203540653302
# sse:11.41816480363336
# sse:11.418164805215811
# sse:11.41816478176354
# sse:11.418164781763277
# found errPDFs0.5022933487261069
# sse:12.951677134617075
# sse:12.951662584019928
# sse:1319.3495025051484
# sse:1319.349519383788
# sse:166.80489583948975
# sse:166.804983264877
# sse:11.071387191437053
# sse:11.071387340745478
# sse:11.071182562143704
# sse:11.071182565956674
# sse:11.071182430522155
# sse:11.071182430520771
# sse:11.071182430521358
# sse:11.071182430521525
# found errPDFs0.5026046640227557
# sse:12.552602222878656
# sse:12.552579958897466
# sse:1311.3247089805554
# sse:1311.324729792334
# sse:248.75508277823255
# sse:248.75517433841617
# sse:8.227289727608696
# sse:8.227290987713888
# sse:8.21287049105418
# sse:8.212870526899914
# sse:8.212858872292436
# sse:8.2128588721945
# sse:8.212858872156602
# sse:8.212858872156517
# found errPDFs0.5039220486907144
# sse:17.426039313201475
# sse:17.42601650350304
# sse:1321.4978094755595
# sse:1321.4978284420058
# sse:268.34564513602606
# sse:268.3457397653726
# sse:12.690232061474585
# sse:12.690232499992742
# sse:12.688427796973407
# sse:12.688427807583071
# sse:12.688426746467307
# sse:12.688426746458827
# sse:12.68842674646231
# sse:12.688426746462497
# found errPDFs0.5041766701539525
# sse:19.482199057852533
# sse:19.48217137323718
# sse:1311.4798281845624
# sse:1311.4798466429781
# sse:334.05837678713993
# sse:334.05847277216947
# sse:13.083917157047686
# sse:13.083919364083979
# sse:13.039779386446838
# sse:13.039779508722525
# sse:13.039644627865885
# sse:13.039644627096866
# sse:13.039644622151972
# sse:13.039644622152334
# found errPDFs0.5047234131870857
# sse:14.600208264137656
# sse:14.6001881762369
# sse:1315.793989711187
# sse:1315.7940073801688
# sse:241.7140444032833
# sse:241.7141392459405
# sse:11.016499611102553
# sse:11.016500059416586
# sse:11.014658899325415
# sse:11.01465891018188
# sse:11.014657825795233
# sse:11.014657825785598
# sse:11.014657825789609
# sse:11.014657825789595
# found errPDFs0.5035899389518607
# sse:19.183115039732744
# sse:19.18308814765967
# sse:1316.1360363320118
# sse:1316.1360531649075
# sse:318.77977481999443
# sse:318.7798697221499
# sse:12.660411945793173
# sse:12.660413565441928
# sse:12.635968655149238
# sse:12.635968694384543
# sse:12.635954384172464
# sse:12.635954384042126
# sse:12.635954383949286
# sse:12.635954383949214
# found errPDFs0.5048807875394157
# sse:19.49244977169159
# sse:19.49242069892818
# sse:1312.7379390972264
# sse:1312.7379571054012
# sse:337.37092393292767
# sse:337.37101962088934
# sse:11.905768082831077
# sse:11.905770019842874
# sse:11.869998429287012
# sse:11.869998510972351
# sse:11.869935107823931
# sse:11.869935107459192
# sse:11.869935106378374
# sse:11.869935106378298
# found errPDFs0.5052965672728671
# sse:17.429502634835114
# sse:17.429481567034912
# sse:1313.5235537545454
# sse:1313.5235740533533
# sse:243.3586860742081
# sse:243.3587800390137
# sse:13.4280799640275
# sse:13.428080652208898
# sse:13.423594216522615
# sse:13.42359424160648
# sse:13.423588272897806
# sse:13.423588272859304
# sse:13.423588272864468
# sse:13.423588272864487
# found errPDFs0.5038443819969045
# sse:17.148397027245718
# sse:17.14837420659897
# sse:1313.4779783573395
# sse:1313.4779976053915
# sse:270.3868955821337
# sse:270.38699163176665
# sse:12.554115028718886
# sse:12.554116110965182
# sse:12.543276762714587
# sse:12.543276800589762
# sse:12.543263534377303
# sse:12.543263534280204
# sse:12.543263534241557
# sse:12.543263534241257
# found errPDFs0.5040706689993212
# sse:18.071679949933763
# sse:18.071652078830198
# sse:1315.8669565364075
# sse:1315.8669776130325
# sse:310.43917065804135
# sse:310.43926472227173
# sse:10.958019240482102
# sse:10.958020541219863
# sse:10.941956887052765
# sse:10.94195692285303
# sse:10.941944768325929
# sse:10.941944768234244
# sse:10.941944768200447
# sse:10.94194476820045
# found errPDFs0.5051395181597279
# RMSE not denoised:0.0011298728220434152
# RMSE denoised:0.00037836860176649104

# %% [markdown]
# ## Robust

# %%
# network.load_state_dict(torch.load('bachelier_with_shorting_250assets_min_var_loss.pth'))


np.random.seed(32)
# block is a sector with bSize assets
nBlocks, bSize, bCorr =10, 50, .5
np.random.seed(0)
mu0, cov0 = formTrueMatrix(nBlocks, bSize, bCorr)
Xs = []

nObs, nTrials, bWidth, shrink, minVarPortf = 10000, 15, .01, False, True
w1 = pd.DataFrame(columns = range(cov0.shape[0]), index = range(nTrials), dtype=float)
w1_d = w1.copy(deep=True)
# w1_n = w1.copy(deep=True)

covs1 = []
covs1_d = []
covs1_n = []
np.random.seed(0)
for i in range(nTrials):
    mu1, cov1, X = simCovMuRob(mu0, cov0, nObs)
    Xs.append(X)
    if minVarPortf: mu1 = None
    cov1_d = deNoiseCov(cov1, nObs*1./cov1.shape[1], bWidth)
    w1.loc[i] = minimize_portfolio_variance(cov1).flatten()   #optPort(cov1, mu1).flatten() # add column vector w as row in w1
    w1_d.loc[i] = minimize_portfolio_variance(cov1_d).flatten() #optPort(cov1_d, mu1).flatten() # np.sum(w1_d, axis=1) is vector of 1's. sum(np.sum(w1_d, axis=0)= nTrials
    # so minimum-variance-portfolio is 1./nTrials*(np.sum(w1_d, axis=0)) - but distribution not stationary
   # tensorX = X_to_tensor(X, lookback)
   # weights_n = network(tensorX)
   # w1_n.loc[i] = weights_n.detach().numpy().flatten()#network(tensorX)
    
    
    covs1.append(cov1)
    covs1_d.append(cov1_d)
    
min_var_port = 1./nTrials*(np.sum(w1_d, axis=0)) 
#code snippet 2.11
w0 = optPort(cov0, None if minVarPortf else mu0) # w0 true percentage asset allocation
w0 = np.repeat(w0.T, w1.shape[0], axis=0) 
rmsd = np.mean((w1-w0).values.flatten()**2)**.5     #RMSE not denoised
rmsd_d = np.mean((w1_d-w0).values.flatten()**2)**.5 #RMSE denoised
#rmsd_n = np.mean((w1_n-w0).values.flatten()**2)**.5 #
print("RMSE not denoised:"+str( rmsd))
print("RMSE denoised:"+str( rmsd_d))
#print("RMSE neural:"+str( rmsd_n))
# Out:
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13892.404992281628438 > -13903.054419875321400). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13886.843039208200935 > -13921.472062477332656). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13904.545688698923186 > -13912.069251621640433). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13909.208592838283948 > -13910.157291741568770). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13884.768825705961717 > -13908.617284603902590). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13890.109238211900447 > -13909.071877626060086). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13894.161645478561695 > -13905.503509512391247). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13884.491891138508436 > -13891.860926126777485). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13891.533867144555188 > -13909.065675943271344). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13901.108222958562692 > -13912.631288416307143). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13921.095104714631816 > -13925.984465054054454). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13913.345624590212537 > -13925.066247369706616). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13875.676560781010267 > -13891.955659618752179). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13877.584585175029133 > -13902.156774788960320). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13876.596167452895315 > -13893.186286187790756). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13893.266234228005487 > -13908.971037114813953). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13896.547917083100401 > -13924.363720683313659). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13896.510576094677162 > -13906.513521700351703). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13890.685074691647969 > -13915.690957828388491). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13903.080347140929007 > -13917.038658129386022). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13887.454866502848745 > -13914.899385333203099). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13909.617344757647516 > -13914.492419911930483). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13894.480353063752773 > -13924.295806238220393). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13886.559653818245351 > -13905.368536950838461). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13890.789802620205592 > -13900.884651315893279). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13895.714039277041593 > -13898.999046834891487). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13891.187963515989395 > -13912.198397941965595). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13888.727523824934906 > -13921.192816643500919). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13894.733581243512162 > -13904.738648504066077). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13887.475577520415754 > -13889.171049196962485). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13880.563938942817913 > -13893.960412772094060). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13882.302471214607067 > -13902.976489121152554). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13899.816128584012404 > -13906.797890178368107). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13891.198644055290060 > -13920.566058400239854). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13901.352732026371086 > -13902.214807502181429). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13903.789498592916061 > -13910.677845377773338). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13913.412014544899648 > -13918.416733847754585). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13905.800547152552099 > -13909.511444982637840). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13900.991339110714762 > -13915.013138589069058). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13881.704754404398045 > -13908.294908258745636). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13888.974727986780636 > -13894.933702688136691). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13893.317114936546204 > -13907.886539150247700). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13889.700057528505567 > -13890.677614834137785). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13888.250148015198647 > -13911.488404914605781). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13910.553081386937265 > -13913.310061644091547). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13906.994782254481834 > -13915.559645989620549). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13884.150603466538087 > -13885.992820745348581). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13881.686611484379682 > -13900.453203657199992). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13897.513550011097323 > -13898.486159839927495). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13891.699502603536530 > -13901.136426084911363). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13894.508568735578592 > -13896.223540618673724). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13882.579517288009811 > -13888.231499580639138). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13886.659786471207553 > -13900.951217767677008). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13892.365155433933978 > -13909.810677108505843). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13886.794472621171735 > -13908.729978036539251). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13872.056081421063936 > -13892.858800648169563). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13880.314577962306430 > -13887.440671307951561). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13879.196055521384551 > -13907.474419905951436). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13883.461559433377261 > -13890.861643090687721). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13893.904389416180493 > -13918.027010922303816). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13888.816564808848852 > -13892.230649137734872). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13885.746447820120011 > -13903.967948584262558). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13908.680664284032900 > -13913.281082089462870). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13899.390323864938182 > -13914.149648105934830). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13907.159303760336115 > -13914.515000835433966). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13896.731344542564329 > -13912.222147592563488). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13898.375742068714317 > -13918.195901397173657). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13904.929342505947716 > -13907.730639805884493). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13897.388462768307363 > -13915.561744117410854). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13902.490130022557423 > -13908.889486173226032). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13901.629946075858243 > -13904.116233911850941). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13885.059867087449675 > -13923.755793295431431). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13882.661022883252372 > -13904.805044905924660). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13895.206341947461624 > -13911.570929778970822). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13879.081143472654730 > -13906.984267338877544). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13897.805014575149471 > -13902.440173358843822). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# sse:135.9296821199424
# sse:135.9296752806249
# sse:1200.7188926012577
# sse:1200.7189037868866
# sse:141.07344612787742
# sse:141.07345797776048
# sse:133.3553185357907
# sse:133.3553184100953
# sse:133.35452507868135
# sse:133.35452508786085
# sse:133.3545208354181
# sse:133.35452083540883
# sse:133.354520835409
# sse:133.3545208354093
# found errPDFs0.507397784153335
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13891.513610482490549 > -13893.780723104639037). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13892.597352873173804 > -13899.555432418457713). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13872.755798900267109 > -13899.563689714184875). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13899.978805086175271 > -13919.481647219672595). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13897.625319415670674 > -13917.199982045211073). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13880.170936199681819 > -13931.670774230242387). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13902.520233264160197 > -13922.102079874111951). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13886.093663251787802 > -13927.732331107723439). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13888.812246749266706 > -13903.281951047849361). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13889.551191800839661 > -13912.752203809368439). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13893.310869034989082 > -13910.805151888387627). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13900.226666193782876 > -13906.014597792793211). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13893.404594427171105 > -13900.681383671257208). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13912.159445329742084 > -13916.389372220919540). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13904.835752020624568 > -13906.587881835339431). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13895.186399482245179 > -13908.836876665734962). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13908.437789431063720 > -13916.027504254436280). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13898.293807505393488 > -13921.913362904260794). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13897.591671491349189 > -13908.393137793087590). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13884.484613659105889 > -13894.764231316958103). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13886.411657605020082 > -13902.085754815363543). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13884.289052892128893 > -13893.607929709014570). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13891.934934102819170 > -13897.379606786364093). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13888.079669035736515 > -13923.949097001308473). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13890.006217664196811 > -13895.479355070952806). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13883.768066158812871 > -13889.935231735105845). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13891.662925662316411 > -13895.253659981055534). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13883.112855198834950 > -13886.709175094374586). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13897.134224624065610 > -13913.074011685766891). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13897.949886535792757 > -13903.151604714259520). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13892.888183878676500 > -13899.516988716246487). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13892.679855348247656 > -13914.553257636909620). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13895.164385043059156 > -13904.145216138860633). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13902.756046176953532 > -13909.210496734178378). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13908.046660752899697 > -13916.805502551855170). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13901.799221569963265 > -13906.710905320411257). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13900.197374729194053 > -13901.933628245873479). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13901.138633215916343 > -13905.526014364331786). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13882.704192748491550 > -13915.848507054492075). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13879.468157198905828 > -13913.428803323808097). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13891.167918812438074 > -13904.020232475393641). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13902.308857189580522 > -13938.210378891222717). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13911.427821140407104 > -13920.926547561581174). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13906.900242076299037 > -13921.600887587850593). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13894.394025129247893 > -13901.277724455032512). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13902.455581358177369 > -13908.633048403382418). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13896.004762827551531 > -13901.967733849245633). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13879.858274962209180 > -13902.863347011965743). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13903.840009241534062 > -13933.118138203306444). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13908.594404717727230 > -13930.799310443606373). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13910.537298528892279 > -13916.751937979062859). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13890.275782018632526 > -13903.851195572853612). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13888.786903923739374 > -13900.010671156578610). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13898.122051260703302 > -13899.288504526371980). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13896.640983052378942 > -13916.642710693244226). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13900.712540902490218 > -13918.524047981700278). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# ...
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13893.295088319253409 > -13908.635104339704412). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13895.419798095639635 > -13904.249977679231961). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13904.609177920890943 > -13916.575420875009513). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13893.412109928211066 > -13905.599919619537104). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13882.020411999645148 > -13888.800129879216911). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13873.084537690041543 > -13897.004231760764014). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13887.764188457178534 > -13897.297690171899376). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13888.868511466675045 > -13901.895243779936209). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13879.210292803403718 > -13908.079045886632230). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13886.039232500310391 > -13918.843959245095903). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13889.727552807456959 > -13902.657530242688154). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13896.394940138132370 > -13907.192747725535810). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13901.523960924660059 > -13904.325404916517073). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13877.503575881857614 > -13933.134459091044846). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13893.882440575840519 > -13899.045887872163803). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13881.496464181382180 > -13883.560254423087827). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13884.098435296709795 > -13898.714345820824747). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13885.355390618047750 > -13921.296104691204164). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13880.182053212298342 > -13902.968555267458214). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13885.939637537874660 > -13899.739048529583670). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13909.047097703631152 > -13919.118434690339200). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13915.582721529586706 > -13921.975937883849838). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13914.971350853951662 > -13917.745821965627329). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13904.635014382549343 > -13914.294817499321653). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13904.769945725867728 > -13920.702570991159519). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13905.946166823301610 > -13916.285640072559545). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13893.694512078005573 > -13912.483346784905734). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13902.167641752534109 > -13903.206898076885409). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13881.327652947562456 > -13901.017638624909523). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13892.261676937121592 > -13897.374152515551032). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# C:\Users\r0913246\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:186: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-13878.975285424978210 > -13906.573920313698181). You may want to try with a higher value of support_fraction (current value: 0.528).
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 21
#      19 np.random.seed(0)
#      20 for i in range(nTrials):
# ---> 21     mu1, cov1, X = simCovMuRob(mu0, cov0, nObs)
#      22     Xs.append(X)
#      23     if minVarPortf: mu1 = None
#
# Cell In[14], line 52, in simCovMuRob(mu0, cov0, nObs)
#      50 x=np.random.multivariate_normal(mu0.flatten(),cov0,size=nObs)
#      51 mu1=x.mean(axis=0).reshape(-1,1)
# ---> 52 cov1=MinCovDet().fit(x).covariance_
#      53 return mu1,cov1, x
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:751, in MinCovDet.fit(self, X, y)
#     747     warnings.warn(
#     748         "The covariance matrix associated to your dataset is not full rank"
#     749     )
#     750 # compute and store raw estimates
# --> 751 raw_location, raw_covariance, raw_support, raw_dist = fast_mcd(
#     752     X,
#     753     support_fraction=self.support_fraction,
#     754     cov_computation_method=self._nonrobust_covariance,
#     755     random_state=random_state,
#     756 )
#     757 if self.assume_centered:
#     758     raw_location = np.zeros(n_features)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:495, in fast_mcd(X, support_fraction, cov_computation_method, random_state)
#     493 high_bound = low_bound + n_samples_subsets
#     494 current_subset = X[samples_shuffle[low_bound:high_bound]]
# --> 495 best_locations_sub, best_covariances_sub, _, _ = select_candidates(
#     496     current_subset,
#     497     h_subset,
#     498     n_trials,
#     499     select=n_best_sub,
#     500     n_iter=2,
#     501     cov_computation_method=cov_computation_method,
#     502     random_state=random_state,
#     503 )
#     504 subset_slice = np.arange(i * n_best_sub, (i + 1) * n_best_sub)
#     505 all_best_locations[subset_slice] = best_locations_sub
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:320, in select_candidates(X, n_support, n_trials, select, n_iter, verbose, cov_computation_method, random_state)
#     316 if not run_from_estimates:
#     317     # perform `n_trials` computations from random initial supports
#     318     for j in range(n_trials):
#     319         all_estimates.append(
# --> 320             _c_step(
#     321                 X,
#     322                 n_support,
#     323                 remaining_iterations=n_iter,
#     324                 verbose=verbose,
#     325                 cov_computation_method=cov_computation_method,
#     326                 random_state=random_state,
#     327             )
#     328         )
#     329 else:
#     330     # perform computations from every given initial estimates
#     331     for j in range(n_trials):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\covariance\_robust_covariance.py:157, in _c_step(X, n_support, random_state, remaining_iterations, initial_estimates, verbose, cov_computation_method)
#     155 previous_support = support
#     156 # compute a new support from the full data set mahalanobis distances
# --> 157 precision = linalg.pinvh(covariance)
#     158 X_centered = X - location
#     159 dist = (np.dot(X_centered, precision) * X_centered).sum(axis=1)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\scipy\linalg\_basic.py:1536, in pinvh(a, atol, rtol, lower, return_rank, check_finite)
#    1469 """
#    1470 Compute the (Moore-Penrose) pseudo-inverse of a Hermitian matrix.
#    1471
#    (...)
#    1533
#    1534 """
#    1535 a = _asarray_validated(a, check_finite=check_finite)
# -> 1536 s, u = _decomp.eigh(a, lower=lower, check_finite=False)
#    1537 t = u.dtype.char.lower()
#    1538 maxS = np.max(np.abs(s))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\scipy\linalg\_decomp.py:579, in eigh(a, b, lower, eigvals_only, overwrite_a, overwrite_b, turbo, eigvals, type, check_finite, subset_by_index, subset_by_value, driver)
#     576     w, v, *other_args, info = drv(a=a1, b=b1, **drv_args, **lwork_args)
#     578 # m is always the first extra argument
# --> 579 w = w[:other_args[0]] if subset else w
#     580 v = v[:, :other_args[0]] if (subset and not eigvals_only) else v
#     582 # Check if we had a  successful exit
#
# KeyboardInterrupt:

# %% [markdown]
# # Check perfomance

# %%
q = nObs / (nBlocks * bSize)

# %%
corr11 = cov2corr(covs1[0])
eVal11, eVec11 = getPCA(corr11)
eMax11, var11 = findMaxEval(np.diag(eVal11), q, bWidth=.01)
nFacts11 = eVal11.shape[0]-np.diag(eVal11)[::-1].searchsorted(eMax11)


var11, nFacts11
# Out:
# sse:10.399669066372272
# sse:10.399671894786536
# sse:3022527575253.238
# sse:3016491575610.4414
# sse:473.7034319371673
# sse:473.70335144392783
# sse:8.312277393585834
# sse:8.312277491688489
# sse:8.310474598291874
# sse:8.310474574806502
# sse:8.310366245957992
# sse:8.310366246113231
# sse:8.310366241292005
# sse:8.310366241292225
# found errPDFs0.4862218327392375
# (0.4862218327392375, 5)

# %%
corr11_d = cov2corr(covs1_d[5])
eVal11_d, eVec11_d = getPCA(corr11_d)
eMax11_d, var11_d = findMaxEval(np.diag(eVal11_d), q, bWidth=.01)
nFacts11_d = eVal11_d.shape[0]-np.diag(eVal11_d)[::-1].searchsorted(eMax11_d)


var11_d, nFacts11_d
# Out:
# sse:18345.153042029204
# sse:18345.152664320565
# sse:9260.121077081712
# sse:9260.121165532631
# found errPDFs0.99999
# (0.99999, 5)

# %% [markdown]
# # NN

# %%
# num_subarrays = 10
# subarray_size = len(X) // num_subarrays
# subarrays = np.array([X[i * subarray_size:(i + 1) * subarray_size] for i in range(num_subarrays)])
 

# subarrays.shape
# Out:
# (10, 100, 250)

# %%
# def get_activation(name):
#     # This function will return a hook function that stores the output in a dictionary
#     def hook(model, input, output):
#         activations[name] = output.detach()
#     return hook

# %%
# inputs_to_allocation_layer = []

# for i in range(lookback, 1000):
#     # Attach the hook to the covariance_layer, which precedes the channel_collapse_layer
#     activations = {}
#     hook = network.portfolio_opt_layer.register_forward_hook(get_activation('portfolio_opt_layer'))

#     # Now run your data through the network. This will store the output of the covariance_layer in activations
#     test_X = X_to_tensor(X, lookback, i)
   
#     network(test_X)

#     # The output you're interested in is now stored in activations['covariance_layer_output']
#     input_to_allocation_layer = activations['portfolio_opt_layer']
#     inputs_to_allocation_layer.append(input_to_allocation_layer)
    
#     # Don't forget to remove the hook when you're done to prevent memory leaks
#     hook.remove()
    
    
# inputs_to_allocation_layer = np.array(inputs_to_allocation_layer)

# %%
# reshaped_inputs = inputs_to_allocation_layer.reshape(960, 250)
# inputs_to_allocation_layer[0, 0, 0], reshaped_inputs[0, 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 reshaped_inputs = inputs_to_allocation_layer.reshape(960, 250)
#       2 inputs_to_allocation_layer[0, 0, 0], reshaped_inputs[0, 0]
#
# NameError: name 'inputs_to_allocation_layer' is not defined

# %%
# q = reshaped_inputs.shape[0]/reshaped_inputs.shape[1]

# %% [markdown]
# ## Getting cov

# %%
test_X = X_to_tensor(X, lookback)
# Out:
# C:\Users\r0913246\AppData\Local\Temp\ipykernel_4108\2520597956.py:238: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(X_tensor, dtype=torch.float32)

# %%
test_X.shape
# Out:
# torch.Size([1, 1, 40, 250])

# %%
cov_n = network.get_covmat(test_X)[0].detach().numpy()

# %%
# cov_n = np.random.normal(size=(4000, 250))
# cov_n = np.cov(cov_n)

# %%
q = 100

# %%
corr11_n = cov2corr(cov_n)
eVal11_n, eVec11_n = getPCA(corr11_n)
eMax11_n, var11_n = findMaxEval(np.diag(eVal11_n), 100, bWidth=.01)
nFacts11_n = eVal11.shape[0]-np.diag(eVal11_n)[::-1].searchsorted(eMax11_n)
nFacts11_n, var11_n
# Out:
# sse:79440.96512236427
# sse:79440.96317654636
# sse:6580.109209273829
# sse:6580.109331054971
# found errPDFs0.99999
# (19, 0.99999)

# %%
# Out:
# (45, 0.99999)
